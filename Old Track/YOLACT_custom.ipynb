# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrutyunjay01/100daysofML/blob/master/YOLACT_custom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/leohsuofnthu/Tensorflow-YOLACT.git
# creates a dir named 'Tensorflow-YOLACT'
# Out:
# Cloning into 'Tensorflow-YOLACT'...
# remote: Enumerating objects: 159, done.
# remote: Counting objects: 100% (159/159), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 1924 (delta 97), reused 110 (delta 63), pack-reused 1765
# Receiving objects: 100% (1924/1924), 2.26 MiB | 4.43 MiB/s, done.
# Resolving deltas: 100% (1271/1271), done.

# %%
! git clone https://github.com/philferriere/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 994, done.
# remote: Total 994 (delta 0), reused 0 (delta 0), pack-reused 994
# Receiving objects: 100% (994/994), 12.26 MiB | 13.75 MiB/s, done.
# Resolving deltas: 100% (589/589), done.

# %%
# %cd ../
# Out:
# /content/cocoapi/PythonAPI

# %%
# !python setup.py build_ext install
# Out:
# Compiling pycocotools/_mask.pyx because it changed.
# [1/1] Cythonizing pycocotools/_mask.pyx
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running build_ext
# building 'pycocotools._mask' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# creating build/temp.linux-x86_64-3.6/pycocotools
# creating build/common
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I../common -I/usr/include/python3.6m -c pycocotools/_mask.c -o build/temp.linux-x86_64-3.6/pycocotools/_mask.o
# ...

# %%
import zipfile

local_zip = "/content/drive/My Drive/custom_dataset.zip"
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall("/content/Tensorflow-YOLACT/data/custom_coco")

# %%
# !python /content/Tensorflow-YOLACT/data/create_coco_tfrecord.py \
  --train_image_dir="/content/Tensorflow-YOLACT/data/custom_coco/custom_dataset/train_images" \
  --val_image_dir="/content/Tensorflow-YOLACT/data/custom_coco/custom_dataset/val_images" \
  --train_annotations_file="/content/Tensorflow-YOLACT/data/custom_coco/custom_dataset/train.json" \
  --val_annotations_file="/content/Tensorflow-YOLACT/data/custom_coco/custom_dataset/val.json" \
  --output_dir="/content/Tensorflow-YOLACT/data/custom_coco/TFdir_custom"
# Out:
# 2020-04-26 21:16:37.867350: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# I0426 21:16:39.420346 140068037535616 create_coco_tfrecord.py:221] Found groundtruth annotations. Building annotations index.
# I0426 21:16:39.420837 140068037535616 create_coco_tfrecord.py:234] 0 images are missing annotations.
# I0426 21:16:39.421521 140068037535616 create_coco_tfrecord.py:239] On image 0 of 125
# 2020-04-26 21:16:39.480245: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-26 21:16:39.526530: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 21:16:39.527203: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# ...

# %%
# !python /content/Tensorflow-YOLACT/train.py \
  --tfrecord_dir /content/Tensorflow-YOLACT/data/custom_coco/TFdir_custom \
  --weights /content/Tensorflow-YOLACT/weights \
  --train_iter 1000 \
  --save_interval 100 \
  --valid_iter 500
# Out:
# 2020-04-26 21:23:01.256540: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# I0426 21:23:02.782095 140155559503744 train.py:84] Creating the dataloader from: /content/Tensorflow-YOLACT/data/custom_coco/TFdir_custom...
# 2020-04-26 21:23:02.816803: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-04-26 21:23:02.835522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-04-26 21:23:02.836106: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %%
# !python yolo.py
# Out:
# 2020-04-26 22:33:05.406912: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1

# %%
import yolo

# %%
model = yolo.make_yolov3_model()
weight_reader = yolo.WeightReader('/content/Tensorflow-YOLACT/yolov3.weights')
weight_reader.load_weights(model)

out = ['conv_81', 'conv_93', 'conv_105']
# Out:
# loading weights of convolution #0
# loading weights of convolution #1
# loading weights of convolution #2
# loading weights of convolution #3
# no convolution #4
# loading weights of convolution #5
# loading weights of convolution #6
# loading weights of convolution #7
# no convolution #8
# loading weights of convolution #9
# loading weights of convolution #10
# no convolution #11
# loading weights of convolution #12
# loading weights of convolution #13
# loading weights of convolution #14
# no convolution #15
# loading weights of convolution #16
# loading weights of convolution #17
# no convolution #18
# loading weights of convolution #19
# loading weights of convolution #20
# no convolution #21
# loading weights of convolution #22
# loading weights of convolution #23
# no convolution #24
# loading weights of convolution #25
# loading weights of convolution #26
# no convolution #27
# loading weights of convolution #28
# loading weights of convolution #29
# no convolution #30
# ...

# %%
from tensorflow.keras import Model
import tensorflow as tf

# %%
b_model = tf.keras.Model(inputs=model.input, outputs=[model.get_layer(x).output for x in out])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-5e73eb6d1f12> in <module>()
# ----> 1 b_model = tf.keras.Model(inputs=model.input, outputs=[model.get_layer(x).output for x in out])
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in __init__(self, *args, **kwargs)
#     165
#     166   def __init__(self, *args, **kwargs):
# --> 167     super(Model, self).__init__(*args, **kwargs)
#     168     _keras_api_gauge.get_cell('model').set(True)
#     169     # Model must be created under scope of DistStrat it will be trained with.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/network.py in __init__(self, *args, **kwargs)
#     171         'inputs' in kwargs and 'outputs' in kwargs):
#     172       # Graph network
# --> 173       self._init_graph_network(*args, **kwargs)
#     174     else:
# ...

# %%
out1 = ['conv3_block4_out', 'conv4_block6_out', 'conv5_block3_out']
base_model = tf.keras.applications.ResNet50(input_shape=(550, 550, 3),
                                                    include_top=False,
                                                    layers=tf.keras.layers,
                                                    weights='imagenet')

# %%
backbone_resnet = tf.keras.Model(inputs=base_model.input,
                                              outputs=[base_model.get_layer(x).output for x in out1])

# %%
backbone_resnet.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 550, 550, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 556, 556, 3)  0           input_5[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 275, 275, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 275, 275, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 275, 275, 64) 0           conv1_bn[0][0]
# ...

# %%
type(model)
# Out:
# keras.engine.training.Model

# %%
type(base_model)
# Out:
# tensorflow.python.keras.engine.training.Model
